# %% [markdown]
# # Fisher's Iris Data Set
#
# This Notebook contains the analysis of Fisher's Iris data set
#
# ![Iris]![image.png](attachment:image.png)
#
# The Data set can be found in the UC Irvine Machine Learning Repositry https://archive.ics.uci.edu/dataset/53/iris

# %% [markdown]
# ## Table of contents
# ***
#
#  - Background
#  - Imports.
#  - Load Data

# %% [markdown]
# ## Background
# ***

# %% [markdown]
# ## Imports
# ***
# Pandas are used for the DataFrame data structure. (https://pandas.pydata.org/)
#
# It allows investigation of CSCV files, amongst other features.
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible. (https://matplotlib.org/)This will be used later in the notebook to find a correlation between two variables
#
# NumPy can be used to perform a wide variety of mathematical operations on arrays.
# It adds powerful data structures to Python that guarantee efficient calculations with arraysand matrices and it supplies an enormous library of high-level mathematical functions that operate on these arrays and matrices. (https://numpy.org/doc/stable/user/absolute_beginners.html)
#
# Seaborn is a Python data visualization library based on matplotlib.
# It provides a high-level interface for drawing attractive and informative statistical graphics.
# Histplot is part of the seaborn package and this will enable me to do my histogram analysis later in the notbook. (https://seaborn.pydata.org/)

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ignoring a warning regarding a change in the figure layout
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Data
# ***

# %%
df = sns.load_dataset('iris')   # loading the iris dataset

# %% [markdown]
# Data is loaded. Now to inspect

# %% [markdown]
# ## Inspection of Data
# ***

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.dropna(inplace=True)   # dropping any missing values

# %%
df.info()   # checking the data types and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.head()   # displaying the first 5 rows of the dataset
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()   # displaying the last 5 rows of the dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape   # checking the number of rows and columns in the dataset
# Out:
# (150, 5)

# %%
df.dtypes   # checking the data types of the columns
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.describe()   # generating descriptive statistics of the dataset
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Histogram of each variable

# %%
plt.figure()
df.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# Scatter plot of each pair of variables

# %%
sns.pairplot(df, hue='species')

# %%
# plot a scatter plot of sepal_length vs sepal_width
plt.figure()
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## References for Code
# https://www.kdnuggets.com/2020/08/5-different-ways-load-data-python.html
#
# https://campus.datacamp.com/courses/data-manipulation-with-pandas/transforming-dataframes?ex=2
#
# https://www.geeksforgeeks.org/writing-to-file-in-python/
#
# https://realpython.com/visualizing-python-plt-scatter/#:~:text=Getting%20Started%20With%20plt.,-scatter()&text=Finally%2C%20you%20create%20the%20scatter,show()%20.

# %% [markdown]
# ***
# ## End
